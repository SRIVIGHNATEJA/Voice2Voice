# %% [markdown]
# # Notebook Reference
#
# This notebook is intentionally kept minimal.
#
# The original exploratory experiments were conducted in Jupyter.
# For reproducibility, execution has been fully migrated to
# script-based modules and a unified pipeline (`run_pipeline.py`).
#
# Please refer to:
# - `models/`
# - `utils/`
# - `run_pipeline.py`
#
# for the reproducible implementation used in experiments.
